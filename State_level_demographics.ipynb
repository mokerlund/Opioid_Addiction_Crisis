# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = "cleaned_data/state_level_hospitalization.csv"
df=pd.read_csv(file_path)
col_drop = ["State","Time Period Date Start","Time Period Date End","State FIPS Code"]

df=df.drop(col_drop,axis=1)
df
# Out:
#    Time Period         Category Demographic Sort Key  \
# 0      CY 2016           Heroin            Statewide
# 1      CY 2016           Heroin            Age Group
# 2      CY 2016           Heroin            Age Group
# 3      CY 2016           Heroin            Age Group
# 4      CY 2016           Heroin       Race/Ethnicity
# 5      CY 2016           Heroin       Race/Ethnicity
# 6      CY 2016           Heroin       Race/Ethnicity
# 7      CY 2016           Heroin     Household Income
# 8      CY 2016           Heroin     Household Income
# 9      CY 2016           Heroin     Household Income
# 10     CY 2016           Heroin     Household Income
# 11     CY 2016           Heroin          Rural/Urban
# 12     CY 2016           Heroin          Rural/Urban
# 13     CY 2016           Heroin          Female/Male
# 14     CY 2016           Heroin          Female/Male
# 15     CY 2016  Pain Medication            Statewide
# 16     CY 2016  Pain Medication            Age Group
# 17     CY 2016  Pain Medication            Age Group
# 18     CY 2016  Pain Medication            Age Group
# 19     CY 2016  Pain Medication       Race/Ethnicity
# 20     CY 2016  Pain Medication       Race/Ethnicity
# 21     CY 2016  Pain Medication       Race/Ethnicity
# 22     CY 2016  Pain Medication     Household Income
# 23     CY 2016  Pain Medication     Household Income
# 24     CY 2016  Pain Medication     Household Income
# 25     CY 2016  Pain Medication     Household Income
# 26     CY 2016  Pain Medication          Rural/Urban
# 27     CY 2016  Pain Medication          Rural/Urban
# 28     CY 2016  Pain Medication          Female/Male
# 29     CY 2016  Pain Medication          Female/Male
# 30     CY 2017           Heroin            Statewide
# 31     CY 2017           Heroin            Age Group
# 32     CY 2017           Heroin            Age Group
# 33     CY 2017           Heroin            Age Group
# 34     CY 2017           Heroin       Race/Ethnicity
# 35     CY 2017           Heroin       Race/Ethnicity
# 36     CY 2017           Heroin       Race/Ethnicity
# 37     CY 2017           Heroin     Household Income
# 38     CY 2017           Heroin     Household Income
# 39     CY 2017           Heroin     Household Income
# 40     CY 2017           Heroin     Household Income
# 41     CY 2017           Heroin          Rural/Urban
# 42     CY 2017           Heroin          Rural/Urban
# 43     CY 2017           Heroin          Female/Male
# 44     CY 2017           Heroin          Female/Male
# 45     CY 2017  Pain Medication            Statewide
# 46     CY 2017  Pain Medication            Age Group
# 47     CY 2017  Pain Medication            Age Group
# 48     CY 2017  Pain Medication            Age Group
# 49     CY 2017  Pain Medication       Race/Ethnicity
# 50     CY 2017  Pain Medication       Race/Ethnicity
# 51     CY 2017  Pain Medication       Race/Ethnicity
# 52     CY 2017  Pain Medication     Household Income
# 53     CY 2017  Pain Medication     Household Income
# 54     CY 2017  Pain Medication     Household Income
# 55     CY 2017  Pain Medication     Household Income
# 56     CY 2017  Pain Medication          Rural/Urban
# 57     CY 2017  Pain Medication          Rural/Urban
# 58     CY 2017  Pain Medication          Female/Male
# 59     CY 2017  Pain Medication          Female/Male
#
#                              Demographic  \
# 0                              Statewide
# 1                           Age 15 to 34
# 2                           Age 35 to 54
# 3                        Age 55 and over
# 4                   Black (non-Hispanic)
# 5                               Hispanic
# 6                   White (non-Hispanic)
# 7        $0 to <$30,000 Household Income
# 8   $30,000 to <$60,000 Household Income
# 9   $60,000 to <$90,000 Household Income
# 10             $90,000+ Household Income
# 11                                 Rural
# 12                                 Urban
# 13                                Female
# 14                                  Male
# 15                             Statewide
# 16                          Age 15 to 34
# 17                          Age 35 to 54
# 18                       Age 55 and over
# 19                  Black (non-Hispanic)
# 20                              Hispanic
# 21                  White (non-Hispanic)
# 22       $0 to <$30,000 Household Income
# 23  $30,000 to <$60,000 Household Income
# 24  $60,000 to <$90,000 Household Income
# 25             $90,000+ Household Income
# 26                                 Rural
# 27                                 Urban
# 28                                Female
# 29                                  Male
# 30                             Statewide
# 31                          Age 15 to 34
# 32                          Age 35 to 54
# 33                       Age 55 and over
# 34                  Black (non-Hispanic)
# 35                              Hispanic
# 36                  White (non-Hispanic)
# 37       $0 to <$30,000 Household Income
# 38  $30,000 to <$60,000 Household Income
# 39  $60,000 to <$90,000 Household Income
# 40             $90,000+ Household Income
# 41                                 Rural
# 42                                 Urban
# 43                                Female
# 44                                  Male
# 45                             Statewide
# 46                          Age 15 to 34
# 47                          Age 35 to 54
# 48                       Age 55 and over
# 49                  Black (non-Hispanic)
# 50                              Hispanic
# 51                  White (non-Hispanic)
# 52       $0 to <$30,000 Household Income
# 53  $30,000 to <$60,000 Household Income
# 54  $60,000 to <$90,000 Household Income
# 55             $90,000+ Household Income
# 56                                 Rural
# 57                                 Urban
# 58                                Female
# 59                                  Male
#
#     Rate of Hospitalizations for Opioid Overdose per 100,000 Residents  \
# 0                                                14.7
# 1                                                26.6
# 2                                                15.9
# 3                                                 3.9
# 4                                                12.4
# 5                                                13.0
# 6                                                15.0
# 7                                                28.8
# 8                                                15.5
# 9                                                12.0
# 10                                               10.0
# 11                                                9.3
# 12                                               16.7
# 13                                                8.5
# 14                                               21.2
# 15                                               16.9
# 16                                               10.2
# 17                                               18.5
# 18                                               21.1
# 19                                               19.6
# 20                                                7.2
# 21                                               17.7
# 22                                               25.3
# 23                                               19.2
# 24                                               13.1
# 25                                                9.8
# 26                                               15.7
# 27                                               17.3
# 28                                               18.1
# 29                                               15.6
# 30                                               16.5
# 31                                               28.8
# 32                                               18.1
# 33                                                5.3
# 34                                               16.7
# 35                                               19.3
# 36                                               16.3
# 37                                               40.5
# 38                                               17.1
# 39                                               13.2
# 40                                                9.9
# 41                                                9.7
# 42                                               19.0
# 43                                                9.4
# 44                                               24.1
# 45                                               16.5
# 46                                               11.0
# 47                                               17.9
# 48                                               19.8
# 49                                               18.5
# 50                                                9.4
# 51                                               17.0
# 52                                               27.5
# 53                                               18.9
# 54                                               11.8
# 55                                               10.4
# 56                                               15.6
# 57                                               16.8
# 58                                               16.1
# 59                                               16.8
#
#                                          Type of Rate
# 0   Rate of hospitalizations for heroin overdose p...
# 1   Rate of hospitalizations for heroin overdose p...
# 2   Rate of hospitalizations for heroin overdose p...
# 3   Rate of hospitalizations for heroin overdose p...
# 4   Rate of hospitalizations for heroin overdose p...
# 5   Rate of hospitalizations for heroin overdose p...
# 6   Rate of hospitalizations for heroin overdose p...
# 7   Rate of hospitalizations for heroin overdose p...
# 8   Rate of hospitalizations for heroin overdose p...
# 9   Rate of hospitalizations for heroin overdose p...
# 10  Rate of hospitalizations for heroin overdose p...
# 11  Rate of hospitalizations for heroin overdose p...
# 12  Rate of hospitalizations for heroin overdose p...
# 13  Rate of hospitalizations for heroin overdose p...
# 14  Rate of hospitalizations for heroin overdose p...
# 15  Rate of hospitalizations for pain medication o...
# 16  Rate of hospitalizations for pain medication o...
# 17  Rate of hospitalizations for pain medication o...
# 18  Rate of hospitalizations for pain medication o...
# 19  Rate of hospitalizations for pain medication o...
# 20  Rate of hospitalizations for pain medication o...
# 21  Rate of hospitalizations for pain medication o...
# 22  Rate of hospitalizations for pain medication o...
# 23  Rate of hospitalizations for pain medication o...
# 24  Rate of hospitalizations for pain medication o...
# 25  Rate of hospitalizations for pain medication o...
# 26  Rate of hospitalizations for pain medication o...
# 27  Rate of hospitalizations for pain medication o...
# 28  Rate of hospitalizations for pain medication o...
# 29  Rate of hospitalizations for pain medication o...
# 30  Rate of hospitalizations for heroin overdose p...
# 31  Rate of hospitalizations for heroin overdose p...
# 32  Rate of hospitalizations for heroin overdose p...
# 33  Rate of hospitalizations for heroin overdose p...
# 34  Rate of hospitalizations for heroin overdose p...
# 35  Rate of hospitalizations for heroin overdose p...
# 36  Rate of hospitalizations for heroin overdose p...
# 37  Rate of hospitalizations for heroin overdose p...
# 38  Rate of hospitalizations for heroin overdose p...
# 39  Rate of hospitalizations for heroin overdose p...
# 40  Rate of hospitalizations for heroin overdose p...
# 41  Rate of hospitalizations for heroin overdose p...
# 42  Rate of hospitalizations for heroin overdose p...
# 43  Rate of hospitalizations for heroin overdose p...
# 44  Rate of hospitalizations for heroin overdose p...
# 45  Rate of hospitalizations for pain medication o...
# 46  Rate of hospitalizations for pain medication o...
# 47  Rate of hospitalizations for pain medication o...
# 48  Rate of hospitalizations for pain medication o...
# 49  Rate of hospitalizations for pain medication o...
# 50  Rate of hospitalizations for pain medication o...
# 51  Rate of hospitalizations for pain medication o...
# 52  Rate of hospitalizations for pain medication o...
# 53  Rate of hospitalizations for pain medication o...
# 54  Rate of hospitalizations for pain medication o...
# 55  Rate of hospitalizations for pain medication o...
# 56  Rate of hospitalizations for pain medication o...
# 57  Rate of hospitalizations for pain medication o...
# 58  Rate of hospitalizations for pain medication o...
# 59  Rate of hospitalizations for pain medication o...

# %% [markdown]
# ## clean age group data

# %%
# clean data for age 
age = df[df["Demographic Sort Key"]=="Age Group"]
age_16 = age[age["Time Period"]=="CY 2016"]
age_17 = age[age["Time Period"]=="CY 2017"]

# %%
# array(['Rate of hospitalizations for heroin overdose per 100000 population',
#        'Rate of hospitalizations for pain medication overdose per 100000 population'],
#       dtype=object)

merge1=age_16[age_16["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=age_16[age_16["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


age_merged_16 = pd.merge(merge1,merge2,on="Demographic")


age_merged_16 = age_merged_16.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2016 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

age_merged_16 = age_merged_16.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2016 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })

age_merged_16
# Out:
#   Time Period_x      Demographic  \
# 0       CY 2016     Age 15 to 34
# 1       CY 2016     Age 35 to 54
# 2       CY 2016  Age 55 and over
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               26.6
# 1                                               15.9
# 2                                                3.9
#
#   Time Period_y  \
# 0       CY 2016
# 1       CY 2016
# 2       CY 2016
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               10.2
# 1                                               18.5
# 2                                               21.1

# %%
merge1=age_17[age_17["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=age_17[age_17["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})

age_merged_17 = pd.merge(merge1,merge2,on="Demographic")

age_merged_17 = age_merged_17.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2017 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

age_merged_17 = age_merged_17.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2017 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })

age_merged_17
# Out:
#   Time Period_x      Demographic  \
# 0       CY 2017     Age 15 to 34
# 1       CY 2017     Age 35 to 54
# 2       CY 2017  Age 55 and over
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               28.8
# 1                                               18.1
# 2                                                5.3
#
#   Time Period_y  \
# 0       CY 2017
# 1       CY 2017
# 2       CY 2017
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               11.0
# 1                                               17.9
# 2                                               19.8

# %%
age_final = pd.merge(age_merged_16,age_merged_17,on="Demographic")

del age_final["Time Period_x_x"]
del age_final["Time Period_y_x"]
del age_final["Time Period_x_y"]
del age_final["Time Period_y_y"]

age_final

# Conclusion:
# 1) young ppl OD herioin, old ppl OD pain meds
# 2) herion has increased, while pain meds was stable from 2016 to 2017
# Out:
#        Demographic  \
# 0     Age 15 to 34
# 1     Age 35 to 54
# 2  Age 55 and over
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               26.6
# 1                                               15.9
# 2                                                3.9
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population  \
# 0                                               10.2
# 1                                               18.5
# 2                                               21.1
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               28.8
# 1                                               18.1
# 2                                                5.3
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               11.0
# 1                                               17.9
# 2                                               19.8

# %% [markdown]
# ## clean up race data

# %%
race = df[df["Demographic Sort Key"]=="Race/Ethnicity"]
race_16 = race[race["Time Period"]=="CY 2016"]
race_17 = race[race["Time Period"]=="CY 2017"]

# %%
merge1=race_16[race_16["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=race_16[race_16["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


race_merged_16 = pd.merge(merge1,merge2,on="Demographic")


race_merged_16 = race_merged_16.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2016 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

race_merged_16 = race_merged_16.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2016 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
race_merged_16
# Out:
#   Time Period_x           Demographic  \
# 0       CY 2016  Black (non-Hispanic)
# 1       CY 2016              Hispanic
# 2       CY 2016  White (non-Hispanic)
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               12.4
# 1                                               13.0
# 2                                               15.0
#
#   Time Period_y  \
# 0       CY 2016
# 1       CY 2016
# 2       CY 2016
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               19.6
# 1                                                7.2
# 2                                               17.7

# %%
merge1=race_17[race_17["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=race_17[race_17["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


race_merged_17 = pd.merge(merge1,merge2,on="Demographic")


race_merged_17 = race_merged_17.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2017 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

race_merged_17 = race_merged_17.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2017 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
race_merged_17
# Out:
#   Time Period_x           Demographic  \
# 0       CY 2017  Black (non-Hispanic)
# 1       CY 2017              Hispanic
# 2       CY 2017  White (non-Hispanic)
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               16.7
# 1                                               19.3
# 2                                               16.3
#
#   Time Period_y  \
# 0       CY 2017
# 1       CY 2017
# 2       CY 2017
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               18.5
# 1                                                9.4
# 2                                               17.0

# %%
race_final = pd.merge(race_merged_16,race_merged_17,on="Demographic")

del race_final["Time Period_x_x"]
del race_final["Time Period_y_x"]
del race_final["Time Period_x_y"]
del race_final["Time Period_y_y"]

race_final

# Conclusion:
# 1) hispatic ppl have pain meds lower OD 
# 2) herion surged amongst hispatic in 2017
# Out:
#             Demographic  \
# 0  Black (non-Hispanic)
# 1              Hispanic
# 2  White (non-Hispanic)
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               12.4
# 1                                               13.0
# 2                                               15.0
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population  \
# 0                                               19.6
# 1                                                7.2
# 2                                               17.7
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               16.7
# 1                                               19.3
# 2                                               16.3
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               18.5
# 1                                                9.4
# 2                                               17.0

# %% [markdown]
# ## Income

# %%
# income in 2016 and 2017
income = df[df["Demographic Sort Key"]=="Household Income"]
income_16 = income[income["Time Period"]=="CY 2016"]
income_17 = income[income["Time Period"]=="CY 2017"]

income_16["Demographic"].unique()

# array(['$0 to <$30,000 Household Income',
#        '$30,000 to <$60,000 Household Income',
#        '$60,000 to <$90,000 Household Income',
#        '$90,000+ Household Income'], dtype=object)
# Out:
# array(['$0 to <$30,000 Household Income',
#        '$30,000 to <$60,000 Household Income',
#        '$60,000 to <$90,000 Household Income',
#        '$90,000+ Household Income'], dtype=object)

# %%
# clean 2016
merge1=income_16[income_16["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=income_16[income_16["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


i_merged_16 = pd.merge(merge1,merge2,on="Demographic")


i_merged_16 = i_merged_16.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2016 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

i_merged_16 = i_merged_16.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2016 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
i_merged_16
# Out:
#   Time Period_x                           Demographic  \
# 0       CY 2016       $0 to <$30,000 Household Income
# 1       CY 2016  $30,000 to <$60,000 Household Income
# 2       CY 2016  $60,000 to <$90,000 Household Income
# 3       CY 2016             $90,000+ Household Income
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               28.8
# 1                                               15.5
# 2                                               12.0
# 3                                               10.0
#
#   Time Period_y  \
# 0       CY 2016
# 1       CY 2016
# 2       CY 2016
# 3       CY 2016
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               25.3
# 1                                               19.2
# 2                                               13.1
# 3                                                9.8

# %%
# clean 2017
merge1=income_17[income_17["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=income_17[income_17["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


i_merged_17 = pd.merge(merge1,merge2,on="Demographic")


i_merged_17 = i_merged_17.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2016 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

i_merged_17 = i_merged_17.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2016 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
i_merged_17
# Out:
#   Time Period_x                           Demographic  \
# 0       CY 2017       $0 to <$30,000 Household Income
# 1       CY 2017  $30,000 to <$60,000 Household Income
# 2       CY 2017  $60,000 to <$90,000 Household Income
# 3       CY 2017             $90,000+ Household Income
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                               40.5
# 1                                               17.1
# 2                                               13.2
# 3                                                9.9
#
#   Time Period_y  \
# 0       CY 2017
# 1       CY 2017
# 2       CY 2017
# 3       CY 2017
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               27.5
# 1                                               18.9
# 2                                               11.8
# 3                                               10.4

# %%
income_final = pd.merge(i_merged_16,i_merged_17,on="Demographic")

income_final=income_final.drop(["Time Period_x_x","Time Period_y_x","Time Period_x_y","Time Period_y_y"],axis=1)

# del race_final["Time Period_x_x"]
# del race_final["Time Period_y_x"]
# del race_final["Time Period_x_y"]
# del race_final["Time Period_y_y"]

income_final

# Conclusion:
# 1) low income people OD more esp heroin 
# 2) high income OD rate did not see increase even in herion
# Out:
#                             Demographic  \
# 0       $0 to <$30,000 Household Income
# 1  $30,000 to <$60,000 Household Income
# 2  $60,000 to <$90,000 Household Income
# 3             $90,000+ Household Income
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population_x  \
# 0                                               28.8
# 1                                               15.5
# 2                                               12.0
# 3                                               10.0
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population_x  \
# 0                                               25.3
# 1                                               19.2
# 2                                               13.1
# 3                                                9.8
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population_y  \
# 0                                               40.5
# 1                                               17.1
# 2                                               13.2
# 3                                                9.9
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population_y
# 0                                               27.5
# 1                                               18.9
# 2                                               11.8
# 3                                               10.4

# %% [markdown]
# ## Gender

# %%
# income in 2016 and 2017
g = df[df["Demographic Sort Key"]=="Female/Male"]
g_16 = g[g["Time Period"]=="CY 2016"]
g_17 = g[g["Time Period"]=="CY 2017"]

g_16["Demographic"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# clean 2016
merge1=g_16[g_16["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=g_16[g_16["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


g_merged_16 = pd.merge(merge1,merge2,on="Demographic")


g_merged_16 = g_merged_16.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2016 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

g_merged_16 = g_merged_16.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2016 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
g_merged_16
# Out:
#   Time Period_x Demographic  \
# 0       CY 2016      Female
# 1       CY 2016        Male
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                                8.5
# 1                                               21.2
#
#   Time Period_y  \
# 0       CY 2016
# 1       CY 2016
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               18.1
# 1                                               15.6

# %%
# clean 2017

merge1=g_17[g_17["Type of Rate"]=="Rate of hospitalizations for heroin overdose per 100000 population"]
merge1=merge1[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge1=merge1.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for heroin overdose per 100000 population"})

merge2=g_17[g_17["Type of Rate"]=="Rate of hospitalizations for pain medication overdose per 100000 population"]
merge2=merge2[["Time Period","Demographic","Rate of Hospitalizations for Opioid Overdose per 100,000 Residents"]]
merge2=merge2.rename(columns=\
              {"Rate of Hospitalizations for Opioid Overdose per 100,000 Residents":\
               "Rate of hospitalizations for pain medication overdose per 100000 population"})


g_merged_17 = pd.merge(merge1,merge2,on="Demographic")


g_merged_17 = g_merged_17.rename(columns={\
                         "Rate of hospitalizations for heroin overdose per 100000 population":\
                           "2017 Rate of hospitalizations for heroin overdose per 100000 population"
                         })

g_merged_17 = g_merged_17.rename(columns={\
                         "Rate of hospitalizations for pain medication overdose per 100000 population":\
                           "2017 Rate of hospitalizations for pain medication overdose per 100000 population"
                         })
g_merged_17
# Out:
#   Time Period_x Demographic  \
# 0       CY 2017      Female
# 1       CY 2017        Male
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                                9.4
# 1                                               24.1
#
#   Time Period_y  \
# 0       CY 2017
# 1       CY 2017
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               16.1
# 1                                               16.8

# %%
gender_final = pd.merge(g_merged_16,g_merged_17,on="Demographic")

gender_final=gender_final.drop(["Time Period_x_x","Time Period_y_x","Time Period_x_y","Time Period_y_y"],axis=1)

gender_final

# Conclusion:
# 1) For herion male def OD a lot more; did not see the difference in pain meds OD
# Out:
#   Demographic  \
# 0      Female
# 1        Male
#
#    2016 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                                8.5
# 1                                               21.2
#
#    2016 Rate of hospitalizations for pain medication overdose per 100000 population  \
# 0                                               18.1
# 1                                               15.6
#
#    2017 Rate of hospitalizations for heroin overdose per 100000 population  \
# 0                                                9.4
# 1                                               24.1
#
#    2017 Rate of hospitalizations for pain medication overdose per 100000 population
# 0                                               16.1
# 1                                               16.8
